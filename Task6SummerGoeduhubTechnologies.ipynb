# %% [markdown]
# ***GO_STP_71: SURAJ SANJEEV PAWAR***

# %% [markdown]
# **Goeduhub Technologies**<br>
# ***https://www.goeduhub.com/***

# %% [markdown]
# **Assignment/Task 6**<br>
# ***Online Summer training on Machine Learning & Data Science With Python***

# %% [markdown]
# ***This assignment is for visualization using Python Matplotlib Library***

# %% [markdown]
# ###***Q.1 Load the necessary package for plotting using pyplot from matplotlib. Example - Days(x-axis) represents 8 days and Speed represents a car’s speed. Plot a Basic line plot between days and car speed, put x axis label as days and y axis label as car speed and put title Car Speed Measurement.***
#          Days=[1,2,3,4,5,6,7,8]
#
#          Speed=[60,62,61,58,56,57,46,63]​​​​​

# %%
#import the library as interactive visualizations in Python
import matplotlib.pyplot as plt 
Days = [1,2,3,4,5,6,7,8]
Speed = [60,62,61,58,56,57,46,63]
#it been creating a line plot
plt.plot(Days, Speed, color = 'Red') 
plt.xlabel('Days')
plt.ylabel('Car Speed')
plt.title('Car Speed Measurement')
plt.grid()
plt.show()

# %% [markdown]
# ###***Q.2 Now to above car data apply some string formats  like line style example green dotted line, marker shape like +, change markersize, markerface color etc.***

# %%
#as import the Days and Speed in the form of list data type
Days = [1,2,3,4,5,6,7,8]
Speed = [60,62,61,58,56,57,46,63]
plt.plot(Days, Speed, color = 'green', marker = '+', ms = 8, mec = 'red', mfc = 'red', linestyle = 'dotted', linewidth = 3.5)
#ms for marker size, mfc for marker face color, mec for border color
plt.xlabel('Days')
plt.ylabel('Car Speed')
plt.title('Car Speed Measurement')
plt.grid()
plt.show()

# %% [markdown]
# ###***Q.3 Plot Axes Labels, Chart title, Legend, Grid in Car minimum, Maximum and average speed in 8 days.***
#
# days=[1,2,3,4,5,6,7,8]
#
# max_speed=[80,91,92,88,77,79,76,75]
#
# min_speed=[42,43,40,42,33,36,34,35]
#
# avg_speed=[46,58,57,56,40,42,41,36]

# %%
days = [1,2,3,4,5,6,7,8]
max_speed = [80,91,92,88,77,79,76,75]
min_speed = [42,43,40,42,33,36,34,35]
avg_speed = [46,58,57,56,40,42,41,36]
plt.figure(figsize=(8,6))
plt.subplot(2,1,1)
plt.plot(Days, max_speed, color = 'red', marker = 'o', ms = 8, mec = 'blue', mfc = 'blue', label = 'Maximum Speed')
plt.xlabel('Days')
plt.ylabel('Maximum Speed')
plt.title('Car Speed Measurement')
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.subplot(2,1,2)
plt.plot(Days, min_speed, color = 'green', marker = 'o', ms = 8, mec = 'black', mfc = 'blue', label = 'Minimum Speed')
plt.xlabel('Days')
plt.ylabel('Maximum Speed')
plt.title('Car Speed Measurement')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ###***Q.4 Plotting a basic sine graph by adding more features. Adding Multiple plots by Superimposition like cosine wave.***

# %%
import numpy as np
x = np.arange(0,4*np.pi,0.1)  
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y, color = 'red', marker='+')
plt.plot(x,z, color = 'blue', marker = 'o')
plt.xlabel('Sin and Cos Value From 0 to 4pi')
plt.ylabel('Sin(x) and Cos(x)')
plt.title('Sin And Cosine Wave')
plt.legend(['sin(X)','Cos(x)'])
plt.show()

# %% [markdown]
# ###***Q.5 Plot Simple bar chart showing popularity of Programming Languages.***
#
# Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
#
# Popularity = [56, 39, 34, 34, 29]
#
# Security = [44 ,36 ,55, 50, 42]
#
# ***Plot Multiple Bars showing Popularity and Security of major Programming Languages. Also Create Horizontal bar chart using barh function.***

# %%
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]
plt.subplot(2,1,1)
plt.bar(Languages, Popularity, width=0.5, color = 'red', align='center')
plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.legend(['Popularity'])
plt.show()
plt.subplot(2,1,2)
plt.bar(Languages, Security, width=0.5, color = 'blue', align='center')
plt.xlabel('Languages')
plt.ylabel('Security')
plt.legend(['Security'])
plt.show()

# %% [markdown]
# Horizontal Bar

# %%
Languages =['Python', 'SQL', 'Java', 'C++', 'JavaScript']
Popularity = [56, 39, 34, 34, 29]
Security = [44 ,36 ,55, 50, 42]
plt.subplot(2,1,1)
plt.barh(Languages, Popularity, color = 'red', align='center')
plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.legend(['Popularity'])
plt.show()
plt.subplot(2,1,2)
plt.barh(Languages, Security, color = 'blue', align='center')
plt.xlabel('Languages')
plt.ylabel('Security')
plt.legend(['Security'])
plt.show()

# %% [markdown]
# ###***Q.6.  Plot Histogram, We have a sample data of Students marks of various Students, we will try to plot number of Students by marks range and try to figure out how many Students are average, below-average and Excellent.***
#
# Marks = [ 61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64]
#
# ***Histogram showing Below Average, Average and Execellent distribution***
#
# 40-60: Below Average
#
# 60-80: Average
#
# 80-100: Excellent

# %%
Marks = np.array([61,86,42,46,73,95,65,78,53,92,55,69,70,49,72,86,64])
below_avg = Marks[np.logical_and(Marks >= 40, Marks < 60)]
avg_marks = Marks[np.logical_and(Marks >= 60, Marks < 80)]
exe_marks = Marks[np.logical_and(Marks >= 80, Marks <= 100)]
plt.hist(Marks)
plt.show()
print('Below Average Students Are : ',below_avg.size)
print('Average Students Are : ',avg_marks.size)
print('Execelent Students Are : ',exe_marks.size)
# Out:
# Below Average Students Are :  5
# Average Students Are :  8
# Execelent Students Are :  4

# %% [markdown]
# ###***Q.7 Titanic Data Set Download Data***
# Load the data file
#
#  (i) Create a pie chart presenting the male/female proportion
#
#  (ii) Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path='drive/My Drive/'
import pandas as pd
df=pd.read_csv(path+"/train_titanicdataset.csv")

# %%
df.head()
df['Sex']
x = df.Sex.value_counts()
x
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
plt.pie(x, autopct='%.0f%%')
plt.legend(['Male','Female'])
plt.title('Male And Female Ratio based on Percentage %')
plt.show()

# %%
male = df[df['Sex']=='male']
male.Sex.value_counts()
female = df[df['Sex']=='female']
female.Sex.value_counts()
plt.scatter(male.Fare, male.Age, label = 'Male', marker = '*')
plt.scatter(female.Fare, female.Age, label = 'Female', marker = '^')
plt.legend()
plt.xlabel('Fare Paid')
plt.ylabel('Age')
plt.grid()
plt.show()

# %% [markdown]
# ***Thank you so much mam and Goeduhub Technologies***
